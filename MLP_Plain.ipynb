# %% [markdown]
# ## MLP 기본 만들기

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms, datasets

# %% [markdown]
# # STEP 01
# 1) Torch.cuda.is_available() : 가능한 gpu가 있는지 확인해서 train에 이용할 device 결정\
# 2) BATCH_SIZE, EPOCHS 등 하이퍼파라미터 결정

# %%
if torch.cuda.is_available() :
    DEVICE = torch.device('cuda')
else :
    DEVICE = torch.device('cpu')

print('Using PyTorch version  : ', torch.__version__, ' Device : ', DEVICE)
# Out:
# Using PyTorch version  :  1.9.0+cu111  Device :  cuda

# %%
BATCH_SIZE = 32
EPOCHS = 10

# %% [markdown]
# # STEP 02
# 1) dataset 과 dataloader 준비
# 2) 데이터 확인하기

# %%
train_dataset = datasets.MNIST(root = "../data/MNIST",
                               train = True,
                               download = True,
                               transform = transforms.ToTensor())
test_dataset = datasets.MNIST(root = "../data/MNIST",
                              train = False,
                              download = True,
                              transform = transforms.ToTensor())
train_loader = torch.utils.data.DataLoader(dataset = train_dataset,
                                           batch_size = BATCH_SIZE,
                                           shuffle = True)
test_loader = torch.utils.data.DataLoader(dataset = test_dataset,
                                          batch_size = BATCH_SIZE,
                                          shuffle = True)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/train-images-idx3-ubyte.gz
# 31.0%IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting ../data/MNIST/MNIST/raw/t10k-images-idx3-ubyte.gz to ../data/MNIST/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 112.7%
# Extracting ../data/MNIST/MNIST/raw/t10k-labels-idx1-ubyte.gz to ../data/MNIST/MNIST/raw

# %%
for (X_train, y_train) in train_loader :
    print('X_train : ', X_train.size(), ' type : ', X_train.type())
    print('y_train : ', y_train.size(), ' type : ', y_train.type())
    break
# Out:
# X_train :  torch.Size([32, 1, 28, 28])  type :  torch.FloatTensor
# y_train :  torch.Size([32])  type :  torch.LongTensor

# %%
pltsize = 1
plt.figure(figsize = (10 * pltsize, pltsize))
for i in range(10) :
    plt.subplot(1, 10, i+1)
    plt.axis('off')
    plt.imshow(X_train[i, :, :, :].numpy().reshape(28, 28), cmap = 'gray_r')
    plt.title('Class : ' + str(y_train[i].item()))

# %% [markdown]
# # STEP 03
# 1) 모델 구조 정의하기
# 2) optimizer, loss function 정의하기

# %%
class Net(nn.Module) :
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(28*28, 512)
        self.fc2 = nn.Linear(512, 256)
        self.fc3 = nn.Linear(256, 10)
    def forward(self, x):
        x = x.view(-1, 28*28)
        x = self.fc1(x)
        x = F.sigmoid(x)
        x = self.fc2(x)
        x = F.sigmoid(x)
        x = self.fc3(x)
        x = F.log_softmax(x, dim = 1)
        return x

# %%
model = Net().to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum = 0.5)
criterion = nn.CrossEntropyLoss()

print(model)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc3): Linear(in_features=256, out_features=10, bias=True)
# )

# %% [markdown]
# # STEP 04
# - train 코드

# %%
def train(model, train_loader, optimizer, log_interval) :
    model.train() # model의 상위 클래스 속 변수 train = True 로 만들어주기
    for batch_idx, (image, label) in enumerate(train_loader) :
        image = image.to(DEVICE)
        label = label.to(DEVICE)
        output = model(image)

        loss = criterion(output, label)
        optimizer.zero_grad() # 이전에 학습할 때 저장된 gradient 없애기
        loss.backward()
        optimizer.step()

        if batch_idx % log_interval == 0:
            print("Train Epoch : {} [ {}/{} ({:.0f}%) ]\tTrain Loss : {:.6f}".format(
                Epoch, batch_idx * len(image), len(train_loader.dataset), 100. * batch_idx / len(train_loader), loss.item()))

# %% [markdown]
# # STEP 05
# - evaluate 코드

# %%
def evaluate(model, test_loader) :
    model.eval() # model의 상위 클래스 속 변수 train = False 로 만들어주기
    test_loss = 0
    correct = 0

    with torch.no_grad() : #train 단계가 아니라 eval 단계이므로 gradient update 못하게 방지
        for image, label in test_loader :
            image = image.to(DEVICE)
            label = label.to(DEVICE)
            output = model(image)
            test_loss += criterion(output, label).item()
            prediction = output.max(1, keepdim = True)[1]
            correct += prediction.eq(label.view_as(prediction)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100. * correct / len(test_loader.dataset)

    return test_loss, test_accuracy

# %% [markdown]
# #STEP 06
# - Train 및 Test 하기

# %%
for Epoch in range(1, EPOCHS+1) :
    train(model, train_loader, optimizer, log_interval=200)
    test_loss, test_accuracy = evaluate(model, test_loader)
    print("\n[Epochh : {}], \tTest Loss : {:.4f}, \tTest Accurary : {:.2f} % \n"
        .format(Epoch, test_loss, test_accuracy))
# Out:
# Train Epoch : 1 [ 0/60000 (0%) ]	Train Loss : 0.368556
# Train Epoch : 1 [ 6400/60000 (11%) ]	Train Loss : 0.412591
# Train Epoch : 1 [ 12800/60000 (21%) ]	Train Loss : 0.246662
# Train Epoch : 1 [ 19200/60000 (32%) ]	Train Loss : 0.273980
# Train Epoch : 1 [ 25600/60000 (43%) ]	Train Loss : 0.369773
# Train Epoch : 1 [ 32000/60000 (53%) ]	Train Loss : 0.167438
# Train Epoch : 1 [ 38400/60000 (64%) ]	Train Loss : 0.464514
# Train Epoch : 1 [ 44800/60000 (75%) ]	Train Loss : 0.199342
# Train Epoch : 1 [ 51200/60000 (85%) ]	Train Loss : 0.299069
# Train Epoch : 1 [ 57600/60000 (96%) ]	Train Loss : 0.300900
#
# [Epochh : 1], 	Test Loss : 0.0104, 	Test Accurary : 90.43 %
#
# Train Epoch : 2 [ 0/60000 (0%) ]	Train Loss : 0.500242
# Train Epoch : 2 [ 6400/60000 (11%) ]	Train Loss : 0.583332
# Train Epoch : 2 [ 12800/60000 (21%) ]	Train Loss : 0.300090
# Train Epoch : 2 [ 19200/60000 (32%) ]	Train Loss : 0.361567
# Train Epoch : 2 [ 25600/60000 (43%) ]	Train Loss : 0.382411
# Train Epoch : 2 [ 32000/60000 (53%) ]	Train Loss : 0.345926
# Train Epoch : 2 [ 38400/60000 (64%) ]	Train Loss : 0.473881
# Train Epoch : 2 [ 44800/60000 (75%) ]	Train Loss : 0.391982
# Train Epoch : 2 [ 51200/60000 (85%) ]	Train Loss : 0.678506
# Train Epoch : 2 [ 57600/60000 (96%) ]	Train Loss : 0.257279
#
# [Epochh : 2], 	Test Loss : 0.0101, 	Test Accurary : 90.68 %
#
# Train Epoch : 3 [ 0/60000 (0%) ]	Train Loss : 0.505982
# Train Epoch : 3 [ 6400/60000 (11%) ]	Train Loss : 0.573629
# Train Epoch : 3 [ 12800/60000 (21%) ]	Train Loss : 0.231370
# Train Epoch : 3 [ 19200/60000 (32%) ]	Train Loss : 0.213345
# Train Epoch : 3 [ 25600/60000 (43%) ]	Train Loss : 0.147445
# Train Epoch : 3 [ 32000/60000 (53%) ]	Train Loss : 0.365376
# Train Epoch : 3 [ 38400/60000 (64%) ]	Train Loss : 0.225467
# Train Epoch : 3 [ 44800/60000 (75%) ]	Train Loss : 0.590888
# Train Epoch : 3 [ 51200/60000 (85%) ]	Train Loss : 0.365365
# Train Epoch : 3 [ 57600/60000 (96%) ]	Train Loss : 0.129726
#
# [Epochh : 3], 	Test Loss : 0.0099, 	Test Accurary : 90.81 %
#
# Train Epoch : 4 [ 0/60000 (0%) ]	Train Loss : 0.131176
# Train Epoch : 4 [ 6400/60000 (11%) ]	Train Loss : 0.105330
# Train Epoch : 4 [ 12800/60000 (21%) ]	Train Loss : 0.546775
# Train Epoch : 4 [ 19200/60000 (32%) ]	Train Loss : 0.444411
# Train Epoch : 4 [ 25600/60000 (43%) ]	Train Loss : 0.360279
# Train Epoch : 4 [ 32000/60000 (53%) ]	Train Loss : 0.223867
# Train Epoch : 4 [ 38400/60000 (64%) ]	Train Loss : 0.215352
# Train Epoch : 4 [ 44800/60000 (75%) ]	Train Loss : 0.214688
# Train Epoch : 4 [ 51200/60000 (85%) ]	Train Loss : 0.478824
# Train Epoch : 4 [ 57600/60000 (96%) ]	Train Loss : 0.588256
#
# [Epochh : 4], 	Test Loss : 0.0095, 	Test Accurary : 91.18 %
#
# Train Epoch : 5 [ 0/60000 (0%) ]	Train Loss : 0.241322
# Train Epoch : 5 [ 6400/60000 (11%) ]	Train Loss : 0.250413
# Train Epoch : 5 [ 12800/60000 (21%) ]	Train Loss : 0.145079
# Train Epoch : 5 [ 19200/60000 (32%) ]	Train Loss : 0.245112
# Train Epoch : 5 [ 25600/60000 (43%) ]	Train Loss : 0.372006
# Train Epoch : 5 [ 32000/60000 (53%) ]	Train Loss : 0.297338
# Train Epoch : 5 [ 38400/60000 (64%) ]	Train Loss : 0.213573
# Train Epoch : 5 [ 44800/60000 (75%) ]	Train Loss : 0.619739
# Train Epoch : 5 [ 51200/60000 (85%) ]	Train Loss : 0.289300
# Train Epoch : 5 [ 57600/60000 (96%) ]	Train Loss : 0.371149
#
# [Epochh : 5], 	Test Loss : 0.0094, 	Test Accurary : 91.35 %
#
# Train Epoch : 6 [ 0/60000 (0%) ]	Train Loss : 0.348217
# Train Epoch : 6 [ 6400/60000 (11%) ]	Train Loss : 0.553944
# Train Epoch : 6 [ 12800/60000 (21%) ]	Train Loss : 0.152583
# Train Epoch : 6 [ 19200/60000 (32%) ]	Train Loss : 0.222599
# Train Epoch : 6 [ 25600/60000 (43%) ]	Train Loss : 0.277187
# Train Epoch : 6 [ 32000/60000 (53%) ]	Train Loss : 0.276234
# Train Epoch : 6 [ 38400/60000 (64%) ]	Train Loss : 0.358928
# Train Epoch : 6 [ 44800/60000 (75%) ]	Train Loss : 0.224564
# Train Epoch : 6 [ 51200/60000 (85%) ]	Train Loss : 0.159628
# Train Epoch : 6 [ 57600/60000 (96%) ]	Train Loss : 0.219862
#
# [Epochh : 6], 	Test Loss : 0.0092, 	Test Accurary : 91.64 %
#
# Train Epoch : 7 [ 0/60000 (0%) ]	Train Loss : 0.470046
# Train Epoch : 7 [ 6400/60000 (11%) ]	Train Loss : 0.229870
# Train Epoch : 7 [ 12800/60000 (21%) ]	Train Loss : 0.257339
# Train Epoch : 7 [ 19200/60000 (32%) ]	Train Loss : 0.369574
# Train Epoch : 7 [ 25600/60000 (43%) ]	Train Loss : 0.424452
# Train Epoch : 7 [ 32000/60000 (53%) ]	Train Loss : 0.161764
# Train Epoch : 7 [ 38400/60000 (64%) ]	Train Loss : 0.379440
# Train Epoch : 7 [ 44800/60000 (75%) ]	Train Loss : 0.326563
# Train Epoch : 7 [ 51200/60000 (85%) ]	Train Loss : 0.179934
# Train Epoch : 7 [ 57600/60000 (96%) ]	Train Loss : 0.201484
#
# [Epochh : 7], 	Test Loss : 0.0091, 	Test Accurary : 91.68 %
#
# Train Epoch : 8 [ 0/60000 (0%) ]	Train Loss : 0.305007
# Train Epoch : 8 [ 6400/60000 (11%) ]	Train Loss : 0.151033
# Train Epoch : 8 [ 12800/60000 (21%) ]	Train Loss : 0.354862
# Train Epoch : 8 [ 19200/60000 (32%) ]	Train Loss : 0.329113
# Train Epoch : 8 [ 25600/60000 (43%) ]	Train Loss : 0.537849
# Train Epoch : 8 [ 32000/60000 (53%) ]	Train Loss : 0.116401
# Train Epoch : 8 [ 38400/60000 (64%) ]	Train Loss : 0.142065
# Train Epoch : 8 [ 44800/60000 (75%) ]	Train Loss : 0.283814
# Train Epoch : 8 [ 51200/60000 (85%) ]	Train Loss : 0.196359
# Train Epoch : 8 [ 57600/60000 (96%) ]	Train Loss : 0.412182
#
# [Epochh : 8], 	Test Loss : 0.0088, 	Test Accurary : 91.97 %
#
# Train Epoch : 9 [ 0/60000 (0%) ]	Train Loss : 0.571523
# Train Epoch : 9 [ 6400/60000 (11%) ]	Train Loss : 0.173547
# Train Epoch : 9 [ 12800/60000 (21%) ]	Train Loss : 0.123288
# Train Epoch : 9 [ 19200/60000 (32%) ]	Train Loss : 0.327672
# Train Epoch : 9 [ 25600/60000 (43%) ]	Train Loss : 0.263591
# Train Epoch : 9 [ 32000/60000 (53%) ]	Train Loss : 0.190210
# Train Epoch : 9 [ 38400/60000 (64%) ]	Train Loss : 0.178553
# Train Epoch : 9 [ 44800/60000 (75%) ]	Train Loss : 0.161109
# Train Epoch : 9 [ 51200/60000 (85%) ]	Train Loss : 0.247596
# Train Epoch : 9 [ 57600/60000 (96%) ]	Train Loss : 0.219928
#
# [Epochh : 9], 	Test Loss : 0.0086, 	Test Accurary : 92.13 %
#
# Train Epoch : 10 [ 0/60000 (0%) ]	Train Loss : 0.261297
# Train Epoch : 10 [ 6400/60000 (11%) ]	Train Loss : 0.758192
# Train Epoch : 10 [ 12800/60000 (21%) ]	Train Loss : 0.168272
# Train Epoch : 10 [ 19200/60000 (32%) ]	Train Loss : 0.404950
# Train Epoch : 10 [ 25600/60000 (43%) ]	Train Loss : 0.512767
# Train Epoch : 10 [ 32000/60000 (53%) ]	Train Loss : 0.309784
# Train Epoch : 10 [ 38400/60000 (64%) ]	Train Loss : 0.227298
# Train Epoch : 10 [ 44800/60000 (75%) ]	Train Loss : 0.209461
# Train Epoch : 10 [ 51200/60000 (85%) ]	Train Loss : 0.289489
# Train Epoch : 10 [ 57600/60000 (96%) ]	Train Loss : 0.331797
#
# [Epochh : 10], 	Test Loss : 0.0086, 	Test Accurary : 92.29 %
